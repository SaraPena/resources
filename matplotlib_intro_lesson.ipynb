# %%
import matplotlib.pylot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c988897a33fb> in <module>
# ----> 1 import matplotlib.pylot as plt
#
# ModuleNotFoundError: No module named 'matplotlib.pylot'

# %%
import matplotlib.pyplot as plt

# %%
print(plt)
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %%
x = list(range(150))

# %%
plt.plot(x)
plt.show()

# %%
# %matplotlib inline

# %%
plt.plot(range(len(x)), x)
plt.show()

# %%
plt.plot(x)
plt.xlim(-20, 200)
plt.ylim(-5,160)
plt.show()

# %%
plt.plot(x, c = 'red')
plt.show()
